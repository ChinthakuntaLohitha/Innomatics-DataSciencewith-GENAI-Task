# %% [markdown]
# 1.The task is to print the string "Hello, World!" using Python.

# %%
if __name__ == '__main__':
    print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# 2.Given an integer n, perform the following conditional actions:
#
# If n is odd, print "Weird"
#
# If n is even and n is in the inclusive range 2 to 5, print "Not Weird"
#
# If n is even and n is in the inclusive range 6 to 20, print "Weird"
#
# If n is even and n is greater than 20, print "Not Weird"

# %%
#!/bin/python3

import math
import os
import random
import re
import sys



if __name__ == '__main__':
    n = int(input().strip())
    if n % 2!= 0:
        print("Weird")
    elif n % 2 == 0 and 2 <= n <= 5:
        print("Not Weird")
    elif n % 2 == 0 and 6 <= n <= 20:
        print("Weird")
    else:
        print("Not Weird")
# Out:
# 4
# Not Weird

# %% [markdown]
# 3.The provided code stub reads two integers from STDIN,  and . Add code to print three lines where:
#
# The first line contains the sum of the two numbers.
#
# The second line contains the difference of the two numbers (first - second).
#
# The third line contains the product of the two numbers.

# %%
if __name__ == '__main__':
    a = int(input())
    b = int(input())
    print(a+b)
    print(a-b)
    print(a*b)
# Out:
# 2
# 4
# 6
# -2
# 8

# %% [markdown]
# 4.The provided code stub reads two integers,  and , from STDIN.
#
# Add logic to print two lines.
#
# The first line should contain the result of integer division,a//b.
#
#  The second line should contain the result of float division,  a/b.

# %%
if __name__ == '__main__':
    a = int(input())
    b = int(input())
    print( a//b)
    print(a/b)
# Out:
# 4
# 2
# 2
# 2.0

# %% [markdown]
# 5.The provided code stub reads an integer, , from STDIN. For all non-negative integers i<n, print i**2.

# %%
if __name__ == '__main__':
    n = int(input())
    for i in range(n):
        print(i**2)
# Out:
# 4
# 0
# 1
# 4
# 9

# %% [markdown]
# 6.Given a year, determine whether it is a leap year.
#
# If it is a leap year, return the Boolean True, otherwise return False.
#
# Note that the code stub provided reads from STDIN and passes arguments to the is_leap function.
#
# It is only necessary to complete the is_leap function.

# %%
def is_leap(year):
    if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
        return True
    else:
        return False

year = int(input())
print(is_leap(year))
# Out:
# 1977
# False

# %% [markdown]
# 7.Print the list of integers from  through  as a string, without spaces.

# %%
if __name__ == '__main__':
    n = int(input())
    for i in range(1,n+1):
       print(i,end='')
# Out:
# 5
# 12345
